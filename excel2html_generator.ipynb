# %% [markdown]
# # Excelファイル → HTML テーブル変換

# %%
import pandas as pd

from funcs.conv import df_to_html

# %%
file_body = 'excel/trader_20250226'
file_excel = '%s.xlsm' % file_body
df = pd.read_excel(file_excel, sheet_name='Transaction')
df
# Out:
#    注文番号        時刻   売買      金額      損益  最大益   最大損                備考
# 0     1  09:08:02   売建  194700     NaN  NaN   NaN    建玉, period = 1
# 1     1  09:08:08   買埋  194700  -250.0   50  -250   損切１, period = 1
# 2     2  09:36:01   売建  193000     NaN  NaN   NaN    建玉, period = 5
# 3     2  09:37:01   買埋  193000  -100.0    0  -200   損切２, period = 6
# 4     3  09:51:01   売建  192050     NaN  NaN   NaN    建玉, period = 1
# 5     3  09:53:52   買埋  192050  -250.0   50  -250   損切１, period = 3
# 6     4  10:01:01   買建  192500     NaN  NaN   NaN    建玉, period = 3
# 7     4  10:04:16   売埋  192500  -250.0  350  -250   損切１, period = 6
# 8     5  10:07:01   売建  191850     NaN  NaN   NaN    建玉, period = 1
# 9     5  10:19:35   買埋  191850   150.0  600     0  利確１, period = 13
# 10    6  10:21:01   買建  191800     NaN  NaN   NaN    建玉, period = 1
# 11    6  10:28:47   売埋  191800  -250.0  200  -250   損切１, period = 8
# 12    7  10:32:01   売建  191400     NaN  NaN   NaN    建玉, period = 3
# 13    7  10:33:12   買埋  191400  -250.0    0  -250   損切１, period = 4
# 14    8  10:56:01   売建  190950     NaN  NaN   NaN    建玉, period = 5
# 15    8  11:11:01   買埋  190950   -50.0  150  -100   返済, period = 19
# 16    9  11:12:01   買建  191150     NaN  NaN   NaN    建玉, period = 1
# 17    9  11:24:01   売埋  191150     0.0  250  -100   返済, period = 12
# 18   10  11:26:01   売建  191000     NaN  NaN   NaN    建玉, period = 2
# 19   10  11:29:26   買埋  191000  -300.0  100  -300   損切１, period = 5
# 20   11  12:32:01   買建  191950     NaN  NaN   NaN    建玉, period = 1
# 21   11  12:35:07   売埋  191950  -250.0  150  -250   損切１, period = 4
# 22   12  13:03:01   買建  191500     NaN  NaN   NaN    建玉, period = 1
# 23   12  13:07:29   売埋  191500  -250.0    0  -250   損切１, period = 5
# 24   13  13:40:00   買建  191200     NaN  NaN   NaN    建玉, period = 1
# 25   13  13:53:00   売埋  191200   -50.0  300   -50   返済, period = 13
# 26   14  13:56:00   売建  191100     NaN  NaN   NaN    建玉, period = 3
# 27   14  14:01:05   買埋  191100  -250.0   50  -250   損切１, period = 8
# 28   15  14:24:00   買建  191650     NaN  NaN   NaN    建玉, period = 1
# 29   15  14:24:50   売埋  191650  -250.0    0  -250   損切１, period = 1
# 30   16  14:37:00   買建  191700     NaN  NaN   NaN    建玉, period = 2
# 31   16  14:46:00   売埋  191700  -100.0  250  -100   返済, period = 10
# 32   17  14:54:00   買建  191850     NaN  NaN   NaN    建玉, period = 1
# 33   17  14:59:00   売埋  191850  -150.0    0  -200   損切２, period = 6
# 34  ---       ---  ---    実現損益 -2850.0  ---   ---               ---

# %%
list_col_format = ['int', 'str', 'str', 'int', 'int', 'int', 'int', 'str']
list_html = df_to_html(df, list_col_format)

file_html = '%s.html' % file_body
with open(file_html, mode='w') as f:
    f.writelines(list_html)
